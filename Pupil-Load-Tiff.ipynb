# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# https://stackoverflow.com/questions/47523534/how-to-improve-intensity-contrast-in-image

# %%
import os
import tifffile as tif
import matplotlib.pyplot as plt


tiff_path='/home/matt/creb/pupil/CREB8'
#file="mjd535_20180616190121.tif"

#tiff_path='/home/matt/Desktop'
file="mjd532_20180606143643.tif"


images= tif.imread(os.path.join(tiff_path,file))
print(images.shape)
# Out:
# (21599, 194, 224)

# %%
import cv2

# %%
img=images[0]

# %%
templateWindowSize

# %%
plt.imshow(img,cmap='gray')

# %%
hist = cv2.equalizeHist(img)
plt.imshow(hist,cmap='gray')

# %%
import numpy as np
kernel =np.ones((1,1),np.uint8)
hist = cv2.fastNlMeansDenoising(img,templateWindowSize=7,h=2,searchWindowSize=15)
hist = cv2.equalizeHist(hist)
hist = cv2.erode(hist,kernel)
plt.imshow(hist,cmap='gray')
